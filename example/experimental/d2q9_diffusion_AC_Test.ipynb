# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

# %%
for i in range(0,50,5):
    f = h5py.File('/home/mdzik/_TCLB/TCLB/output/allen_cahn/d2q9_diffusion_AC_Test_HDF5_%08d.h5'%i)    
    plt.plot(f['DRE_1'][0,25,:])

# %%
S = list()
I = list()
R = list()

for i in range(0,50,5):
    f = h5py.File('/home/mdzik/_TCLB/TCLB/output/allen_cahn/d2q9_diffusion_SIRLaplace_Test_HDF5_%08d.h5'%i)    
    #plt.plot(f['DRE_1'][0,25,:])
    S.append( f['DRE_1'][0,0,0] )
    I.append( f['DRE_2'][0,0,0] )
    R.append( f['DRE_3'][0,0,0] )
    
    
plt.plot(S)
plt.plot(I)
plt.plot(R)

print(S)
# Out:
# [450.9, -143495.03949003405, -2890480.7646323075, -34504020.13109997, -338773266.90578115, -3026755833.5242205, -25730314822.915947, -211329822450.53857, -1700768199450.31, -10404464427785.895]
